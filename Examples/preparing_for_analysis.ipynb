# %% [markdown]
# # Example of reading data and saving it into json

# %%
PATH = '' # Where the repository was cloned
import sys
sys.path.append(PATH)

from Code.visualization import plot_signal
from Code.utilities import read_signal, write_data_to_json, read_signal_from_json

# %%
SIGNAL_PATH = ''
signal = read_signal(SIGNAL_PATH, signal_name='fvr', sep=';')

# %%
JSON_PATH = '' #Path to a json Path or Path where the json file should be saved
#Example: 'D:/sonata_dataset/Data/json.json'
write_data_to_json(JSON_PATH, signal, 'fvr')

# %%
signal = read_signal(SIGNAL_PATH, signal_name='abp_cnap[mmHg]', sep=';')

# %%
JSON_PATH = '' #Path to the json file 
#Example: 'D:/sonata_dataset/Data/json.json'
write_data_to_json(JSON_PATH, signal, 'abp')

# %%
file_path = '' # Path to your JSON file
signal_name = 'abp' # Name of the signal you want to plot

# %%
signal_data = read_signal_from_json(file_path, signal_name)
if signal_data is not None:
    plot_signal(signal_data)
